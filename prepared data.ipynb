# %%
import os 
import shutil 
import glob 
import random
from tqdm import tqdm

# %%
Raw_DIR= r'C:\Users\acer\Desktop\Untitled Folder\mrl_eye data set'
for dirpath, dirname, filename in os.walk(Raw_DIR):
    for file in tqdm([f for f in filename if f.endswith('.png')]):
        if file.split('_')[4] == '0':
             shutil.copy(src=dirpath + '/' + file, dst= r'C:\Users\acer\Desktop\Untitled Folder\data\close eyes') 
                
        elif file.split('_')[4] == '1':
            
            
                shutil.copy(src=dirpath + '/' + file, dst= r'C:\Users\acer\Desktop\Untitled Folder\data\open eyes')
# Out:
# 0it [00:00, ?it/s]
# ...
# 100%|███████████████████████████████████████████████████████████████████████████| 10257/10257 [00:27<00:00, 368.68it/s]
